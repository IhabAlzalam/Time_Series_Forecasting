# %% [markdown]
# # Import libraries and data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Forecasting Models and Time Series for Business in Python
# Out:
# /content/drive/MyDrive/Forecasting Models and Time Series for Business in Python

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#get the data
data = pd.read_csv("Daily Bike Sharing.csv", 
                   index_col = "dteday", 
                   parse_dates = True)
data.head(1)
# Out:
#             instant  season  yr  mnth  holiday  weekday  workingday  \
# dteday
# 2011-01-01        1       1   0     1        0        6           0
#
#             weathersit      temp     atemp       hum  windspeed  casual  \
# dteday
# 2011-01-01           2  0.344167  0.363625  0.805833   0.160446     331
#
#             registered  cnt
# dteday
# 2011-01-01         654  985

# %%
#select variables
dataset = data.cnt.rename("y")
dataset.head(1)
# Out:
# dteday
# 2011-01-01    985
# Name: y, dtype: int64

# %% [markdown]
# #Data Transformation

# %%
#index
dataset = dataset.asfreq("D")
dataset.index
# Out:
# DatetimeIndex(['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04',
#                '2011-01-05', '2011-01-06', '2011-01-07', '2011-01-08',
#                '2011-01-09', '2011-01-10',
#                ...
#                '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25',
#                '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29',
#                '2012-12-30', '2012-12-31'],
#               dtype='datetime64[ns]', name='dteday', length=731, freq='D')

# %% [markdown]
# #Visualization

# %%
#viz
dataset.plot(figsize = (10, 7), legend = True)

# %% [markdown]
# #Training and Test Set

# %%
#Training and test set
test_days = 31
training_set = dataset.iloc[:-test_days]
test_set = dataset.iloc[-test_days:]
test_set.tail(1)
# Out:
# dteday
# 2012-12-31    2729
# Freq: D, Name: y, dtype: int64

# %% [markdown]
# #load predictions

# %%
#change directory
# %cd /content/drive/MyDrive/Forecasting Models and Time Series for Business in Python/0. Ensemble
# Out:
# /content/drive/MyDrive/Forecasting Models and Time Series for Business in Python/0. Ensemble

# %%
#load predictions
hw = pd.read_csv("predictions_hw.csv", index_col= [0], parse_dates=True)
tbats = pd.read_csv("predictions_tbats.csv", index_col= [0], parse_dates=True)
sarimax = pd.read_csv("predictions_sarimax.csv", index_col= [0], parse_dates=True)
tfp = pd.read_csv("predictions_tfp.csv", index_col= [0], parse_dates=True)
prophet_tuned = pd.read_csv("predictions_prophet_tuned.csv", index_col= [0], parse_dates=True)
xgboost = pd.read_csv("predictions_xgb.csv", index_col= [0], parse_dates=True)

# %%
#concatenate predictions
df = pd.concat([test_set,hw, tbats, sarimax, tfp, prophet_tuned, xgboost], axis = 1)
df.head()
# Out:
#                y           HW        TBATS      SARIMAX          TFP  \
# 2012-12-01  5191  4703.434234  4828.272249  4288.680992  4216.556140
# 2012-12-02  4649  4152.109049  4482.064414  4216.703531  3480.177103
# 2012-12-03  6234  4376.195688  4362.513961  5448.271150  4422.606101
# 2012-12-04  6606  4211.156937  4305.123489  5427.577928  4503.671822
# 2012-12-05  5729  4896.528749  4260.338328  5448.958443  4675.644485
#
#             prophet_tuned    XGBoost
# 2012-12-01    4113.640588  3945.4434
# 2012-12-02    3488.968320  2902.8472
# 2012-12-03    5613.070180  6258.6740
# 2012-12-04    5597.516900  6413.3410
# 2012-12-05    5310.016966  6116.5730

# %% [markdown]
# #Ensemble forecast

# %%
df["ensemble"] = df.iloc[:,1:].mean(axis = 1)
df.head()
# Out:
#                y           HW        TBATS      SARIMAX          TFP  \
# 2012-12-01  5191  4703.434234  4828.272249  4288.680992  4216.556140
# 2012-12-02  4649  4152.109049  4482.064414  4216.703531  3480.177103
# 2012-12-03  6234  4376.195688  4362.513961  5448.271150  4422.606101
# 2012-12-04  6606  4211.156937  4305.123489  5427.577928  4503.671822
# 2012-12-05  5729  4896.528749  4260.338328  5448.958443  4675.644485
#
#             prophet_tuned    XGBoost     ensemble
# 2012-12-01    4113.640588  3945.4434  4349.337934
# 2012-12-02    3488.968320  2902.8472  3787.144936
# 2012-12-03    5613.070180  6258.6740  5080.221847
# 2012-12-04    5597.516900  6413.3410  5076.398013
# 2012-12-05    5310.016966  6116.5730  5118.009995

# %% [markdown]
# #Viz

# %%
#visualization
df.y.plot(figsize = (9,6), legend = True)
df.XGBoost.plot(legend  = True)
df.prophet_tuned.plot(legend = True)
df.SARIMAX.plot(legend = True)

# %%
df.plot(figsize = (9,6), legend = True)

# %% [markdown]
# #Model assessment

# %%
#MAE and RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
print(round(mean_absolute_error(df.y, df.ensemble),0))
print(round(np.sqrt(mean_squared_error(df.y, df.ensemble)), 0))
print(mean_absolute_percentage_error(df.y, df.ensemble))
# Out:
# 1110.0
# 1273.0
# 0.5858099306429905

# %%
#MAPE function
def MAPE(y_true, y_pred):
  y_true, y_pred = np.array(y_true), np.array(y_pred)
  return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
MAPE(df.y, df.ensemble)
# Out:
# 58.58099306429905
